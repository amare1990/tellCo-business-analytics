# %%
# Get the parent directory and insert into the system path
import os, sys
parent_dir = os.path.dirname(os.getcwd())
sys.path.insert(0, parent_dir)

# %%
from scripts.eda_user_analysis import ExploratoryDataAnalysis
eda_user = ExploratoryDataAnalysis()

# %%
cleaned_data = eda_user_overview.treat_missing_values()

# %%
cleaned_data.shape
# Out:
# (150001, 55)

# %%
transformed_data, decile_data = eda_user.variable_transformations()

# %%
transformed_data.shape
# Out:
# (150001, 58)

# %%
decile_data
# Out:
#    decile    total_data
# 0       1  1.488404e+13
# 1       2  2.361997e+13
# 2       3  6.089083e+12
# 3       4  1.485375e+13
# 4       5  1.491834e+13

# %%
basic_stat_metrics = eda_user.basic_metrics()

# %%
basic_stat_metrics
# Out:
#           Bearer Id       Start ms         End ms     Dur. (ms)          IMSI  \
# count  1.500010e+05  150001.000000  150001.000000  1.500010e+05  1.500010e+05
# mean   1.013887e+19     499.188200     498.800880  1.046086e+05  2.082016e+14
# std    2.883600e+18     288.610872     288.096693  8.103735e+04  2.144722e+10
# min    6.917538e+18       0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%    7.349883e+18     250.000000     251.000000  5.744200e+04  2.082014e+14
# 50%    7.349883e+18     499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%    1.304243e+19     749.000000     750.000000  1.324300e+05  2.082018e+14
# max    1.318654e+19     999.000000     999.000000  1.859336e+06  2.140743e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   1.500010e+05  1.500010e+05    150001.000000    150001.000000
# mean    4.188282e+10  4.847455e+13       109.795706        17.662883
# ...

# %%
# Non-graphical univariante analysis
dispersion_params = eda_user.univariate_analysis(isp

# %%
dispersion_params
# Out:
# Bearer Id                                   8.315146e+36
# Start ms                                    8.329624e+04
# End ms                                      8.299970e+04
# Dur. (ms)                                   6.567052e+09
# IMSI                                        4.599834e+20
# MSISDN/Number                               5.947410e+24
# IMEI                                        5.005776e+26
# Avg RTT DL (ms)                             3.128642e+05
# Avg RTT UL (ms)                             5.856831e+03
# Avg Bearer TP DL (kbps)                     5.746471e+08
# Avg Bearer TP UL (kbps)                     2.139377e+07
# TCP DL Retrans. Vol (Bytes)                 1.374418e+16
# TCP UL Retrans. Vol (Bytes)                 2.488873e+14
# DL TP < 50 Kbps (%)                         1.691358e+02
# 50 Kbps < DL TP < 250 Kbps (%)              3.843494e+01
# 250 Kbps < DL TP < 1 Mbps (%)               1.721478e+01
# ...

# %%
# Plot univariate variables
eda_user.graphical_univariate_analysis()

# %%
# Bivariante plotting
eda_user_overview.bivariate_analysis()

# %%
# Correlation analysis ploting
eda_user_overview.correlation_analysis()
